# %% [markdown]
# # WEB SCRAPPING ASSIGNMENT - 2

# %% [markdown]
# # 1. First 10 jobs for Data Analyst

# %%
import pandas as pd
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
url = 'https://www.naukri.com/'
driver.get(url)

# %%
#using xpath -
search_job = driver.find_element_by_xpath('//input[@class="sugInp"]')
search_job
#search_btn = driver.find_element_by_class_name('btn') will also work here

# %%
search_job.send_keys("Data Analyst")

# %%
search_loc = driver.find_element_by_id("qsb-location-sugg")
search_loc.send_keys("Bangalore")

# %%
search_btn = driver.find_element_by_xpath('//button[@class="btn"]')
search_btn

# %%
search_btn.click()

# %%
titles_tags = driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
titles_tags

# %%
job_titles =[]
for i in titles_tags:
    job_titles.append(i.text)
job_titles

# %%
import pandas as pd
jobs=pd.DataFrame({})
jobs ['titles'] = job_titles
jobs.head(10)

# %% [markdown]
# # 2. First 10 jobs for Data Scientist

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
url = 'https://www.naukri.com/'
driver.get(url)

# %%
#using id -
search_job = driver.find_element_by_id("qsb-keyword-sugg")
search_job

# %%
#using xpath -
search_job = driver.find_element_by_xpath('//input[@class="sugInp"]')
search_job

# %%
search_job.send_keys("Data Scientist")

# %%
search_loc = driver.find_element_by_id("qsb-location-sugg")
search_loc.send_keys("Bangalore")

# %%
search_btn = driver.find_element_by_xpath('//button[@class="btn"]')
search_btn

# %%
search_btn.click()

# %%
urls = []
for in driver.find_element_by_xpath('//a[@class="title fw500 ellipsis"]'):
    urls.append(i.get_attribute("href"))

# %%
urls

# %%
len(urls)

# %%
titles_tags = driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
titles_tags

# %%
job_titles=[]
job_description=[]

# %%
for i in urls :
    driver.get(i)
    time.sleep(3)
    #fetching for job title
    try :
        job=driver.find_element_by_xpath('//h1[@class="jd-header-title"]')
        job_title.append(job.next.replace(''/n',"new line"))
    except :
        job_title.append('_')
       
        #fetching for job description
        try:
          job_desc=driver.find_element_by_xpath('//section[@class="job_desc"]')
          job_title.append('job_desc.text')                
        except:
          job_description.append('_')

# %%
print(len('job_title'))
print(len('job_description'))

# %%
job_title

# %%
job_description

# %% [markdown]
# # 3.

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
url = 'https://www.naukri.com/'
driver.get(url)

# %% [markdown]
# # 4.

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
url = 'https://www.glassdoor.co.in/index.htm/'
driver.get(url)

# %%
search_job = driver.find_element_by_xpath('//[@class=""]')
search_job

# %%
search_job.send_keys("Data Scientist")

# %%
search_loc = driver.find_element_by_id("qsb-location-sugg")
search_loc.send_keys("Noida")

# %%
search_btn = driver.find_element_by_xpath('//button[@class="btn"]')
search_btn

# %%
search_btn.click()

# %%
company_name = driver.find_elements_by_xpath("//[@class='']")
company_name

# %%
posted = driver.find_elements_by_xpath("//[@class='']")
posted

# %%
company_rating = driver.find_elements_by_xpath("//[@class='']")
company_rating

# %%
company = []
for i in company_name:
    company_name.append(i.text)
company_name

# %%
company rating =[]
for i in company_rating:
    company_rating.append(i.text)
company_rating

# %%
job posted =[]
for i in posted:
    posted.append(i.text)
posted

# %%
import pandas as pd
jobs=pd.DataFrame({})
company ['titles'] = company_name
job posted ['posted'] = posted
rating ['rating'] = company_rating
jobs.head(10)

# %% [markdown]
# # 5.

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
url = 'https://www.glassdoor.co.in/Salaries/index/'
driver.get(url)

# %%
search_job = driver.find_element_by_xpath('//[@class=""]')
search_job

# %%
search_job.send_keys("Data Scientist")

# %%
search_loc = driver.find_element_by_id("qsb-location-sugg")
search_loc.send_keys("Noida")

# %%
search_btn = driver.find_element_by_xpath('//button[@class="btn"]')
search_btn

# %%
search_btn.click()

# %%
company_name = driver.find_elements_by_xpath("//[@class='']")
company_name

# %%
min_sal = driver.find_elements_by_xpath("//[@class='']")
min_sal

# %%
avg_sal = driver.find_elements_by_xpath("//[@class='']")
avg_sal

# %%
max_sal = driver.find_elements_by_xpath("//[@class='']")
max_sal

# %%
company = []
for i in company_name:
    company_name.append(i.text)
company_name

# %%
minimum salary = []
for i in min_sal:
    min_sal.append(i.text)
min_sal

# %%
avarage salary = []
for i in avg_sal:
    avg_sal.append(i.text)
avg_sal

# %%
maximum salary = []
for i in max_sal:
    max_sal.append(i.text)
max_sal

# %%
import pandas as pd
jobs=pd.DataFrame({})
company ['titles'] = company_name
min_sal ['minimum salary'] = min_sal
avg_sal ['average salary'] = avg_sal
max_sal ['maximum salary'] = max_sal
jobs.head(10)

# %% [markdown]
# # 6.

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
url = 'https://www.flipkart.com/'
driver.get(url)

# %%
search = driver.find_element_by_xpath("""//*[@id="container"]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input""")

# %%
search.send_keys("Sunglasses")

# %%
search.submit()

# %%
urls=[]
for i in driver.find_elements_by_xpath('//a[@class="IRpwTa"]'):
    urls.append(i.get_attribute('href'))

# %%
urls

# %%
brand=[]
product_desc=[]
price=[]
discount=[]

# %%
for i in urls:
    driver.get(i)
    time.sleep(3)
    try:
        brand=driver.file_element_by_xpath("//h1[@class='yhB1nd']").get_attribute('text')
        brand.append(brand.text.replace("/n", 'new line'))
    except:
        brand.append("-")
        
    try:
        product_desc=driver.file_element_by_xpath("//div[@class='_2yIA0Y']")
        product_desc.append(brand.text.replace("/n", 'new line'))
    except:
        product_desc.append("-")
        
    try:
        discount=driver.file_element_by_xpath("//div[@class='_3Ay6Sb _31Dcoz pZkvcx']")
        discount.append(brand.text.replace("/n", 'new line'))
    except:
        discount.append("-")    
        
        
    try:
        price=driver.file_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']")
        price.append(brand.text.replace("/n", 'new line'))
    except:
        price.append("-")
